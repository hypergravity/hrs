# %%
from song import measure_xdrift

# %%
dp = '/hydrogen/song/star_spec/20161206/night/raw/'

# %%
t = measure_xdrift.scan_files(dp)
# Out:
# **scan_fits_header**: 100%|██████████████████████████████████| 1089/1089 [01:03<00:00, 17.11 file/s]

# %%
t2, fig = measure_xdrift.check_xdrift(t)
# Out:
# WARNING: VerifyWarning: Keyword name 'subtract_bias' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# **measure_xshift_2dcorr**:   0%|                                          | 0/40 [00:00<?, ? file/s]
# 480 BIAS found
# 480 FLAT found
# 40 FLATI2 found
# 16 THAR found
# 62 STAR found
# ----- FLATI2 -----
# **measure_xshift_2dcorr**: 100%|█████████████████████████████████| 40/40 [00:09<00:00,  4.17 file/s]
# **measure_xshift_2dcorr**:   0%|                                         | 0/480 [00:00<?, ? file/s]
# ------ FLAT ------
# **measure_xshift_2dcorr**: 100%|███████████████████████████████| 480/480 [01:57<00:00,  4.00 file/s]
# **measure_xshift_2dcorr**:   0%|                                          | 0/16 [00:00<?, ? file/s]
# ------ THAR ------
# **measure_xshift_2dcorr**: 100%|█████████████████████████████████| 16/16 [00:03<00:00,  4.08 file/s]
# **measure_xshift_2dcorr**:   0%|                                          | 0/62 [00:00<?, ? file/s]
# ------ STAR ------
# **measure_xshift_2dcorr**: 100%|█████████████████████████████████| 62/62 [00:15<00:00,  4.06 file/s]

# %%
fig

# %%
fig.savefig('/hydrogen/song/figs/Xdrift_20161206.svg')

# %%
t.write('/hydrogen/song/figs/file_catalog_20161206.fits')
# Out:
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---M----'). [astropy.io.fits.column]
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---O----'). [astropy.io.fits.column]
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---TI---'). [astropy.io.fits.column]
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---C----'). [astropy.io.fits.column]
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---SP---'). [astropy.io.fits.column]
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---SM---'). [astropy.io.fits.column]
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---TEL--'). [astropy.io.fits.column]
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---W----'). [astropy.io.fits.column]
